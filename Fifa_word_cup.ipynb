# %%
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fifa = pd.read_csv("G://DataScience project practice//FIFA_data.csv")

# %%
fifa.head(20)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
# 15          15  211110          P. Dybala   24
# 16          16  202126            H. Kane   24
# 17          17  194765       A. Griezmann   27
# 18          18  192448      M. ter Stegen   26
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# Unnamed: 0
# ID
# Name
# Age
# Photo
# Nationality
# Flag
# Overall
# Potential
# Club
# Club Logo
# Value
# Wage
# Special
# Preferred Foot
# International Reputation
# Weak Foot
# Skill Moves
# Work Rate
# Body Type
# Real Face
# Position
# Jersey Number
# Joined
# Loaned From
# Contract Valid Until
# Height
# Weight
# LS
# ST
# RS
# LW
# LF
# CF
# RF
# RW
# LAM
# CAM
# RAM
# LM
# LCM
# CM
# RCM
# RM
# LWB
# LDM
# CDM
# RDM
# RWB
# LB
# LCB
# CB
# RCB
# RB
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# Release Clause

# %%
del fifa['Unnamed: 0']

# %%
fifa.drop('Photo',axis = 1 ,inplace = True)

# %%
fifa.head()
# Out:
#        ID               Name  Age Nationality  \
# 0  158023           L. Messi   31   Argentina
# 1   20801  Cristiano Ronaldo   33    Portugal
# 2  190871          Neymar Jr   26      Brazil
# 3  193080             De Gea   27       Spain
# 4  192985       K. De Bruyne   27     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo    Value  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  €110.5M
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png     €77M
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  €118.5M
# ...

# %%
fifa.drop('Flag',axis = 1 ,inplace = True)
fifa.drop('Club Logo',axis = 1 ,inplace = True)

# %%
fifa.shape
# Out:
# (18207, 85)

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 85 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     18207 non-null  object
#  8   Wage                      18207 non-null  object
#  9   Special                   18207 non-null  int64
#  10  Preferred Foot            18159 non-null  object
#  11  International Reputation  18159 non-null  float64
#  12  Weak Foot                 18159 non-null  float64
# ...

# %%
fifa["Nationality"].value_counts()
# Out:
# Nationality
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
#                         ...
# New Caledonia              1
# Fiji                       1
# São Tomé & Príncipe        1
# United Arab Emirates       1
# Botswana                   1
# Name: count, Length: 164, dtype: int64

# %%
fifa["Nationality"].value_counts()[0:10]
# Out:
# Nationality
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: count, dtype: int64

# %%
fifa["Nationality"].value_counts()[0:5]
# Out:
# Nationality
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: count, dtype: int64

# %%
fifa["Nationality"].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object', name='Nationality')

# %%
fifa["Nationality"].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'Argentina', 'France'], dtype='object', name='Nationality')

# %%
fifa.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Nationality          0
# Overall              0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 85, dtype: int64

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Special', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined',
#        'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST',
#        'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM',
#        'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing',
#        'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions',
#        'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
# ...

# %%
ax=sns.countplot(x="Skill Moves",data=fifa)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(x="Crossing", data=fifa)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(x="Nationality",data=fifa)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(x="SlidingTackle",data=fifa)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
fifa["Age"].value_counts().head(5)
# Out:
# Age
# 21    1423
# 26    1387
# 24    1358
# 22    1340
# 23    1332
# Name: count, dtype: int64

# %%
fifa["Age"].value_counts().head(5)
ax = sns.countplot(data=fifa,x="Age")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
plt.figure(figsize=(7,5))
plt.bar(list(fifa["Nationality"].value_counts()[0:5].keys()),list(fifa["Nationality"].value_counts()[0:5]),color=["red","green","blue","yellow","pink"])
plt.show()

# %%
fifa.Name.head()
# Out:
# 0             L. Messi
# 1    Cristiano Ronaldo
# 2            Neymar Jr
# 3               De Gea
# 4         K. De Bruyne
# Name: Name, dtype: object

# %%
fifa.GKKicking.head()
# Out:
# 0    15.0
# 1    15.0
# 2    15.0
# 3    87.0
# 4     5.0
# Name: GKKicking, dtype: float64

# %%
fifa.ID.head()
# Out:
# 0    158023
# 1     20801
# 2    190871
# 3    193080
# 4    192985
# Name: ID, dtype: int64

# %%
fifa.Age.head()
# Out:
# 0    31
# 1    33
# 2    26
# 3    27
# 4    27
# Name: Age, dtype: int64

# %%
fifa.Finishing.head()
# Out:
# 0    95.0
# 1    94.0
# 2    87.0
# 3    13.0
# 4    82.0
# Name: Finishing, dtype: float64

# %%
to_impute_by_mode = fifa.loc[:, ['Body Type','International Reputation', 'Height', 'Weight', 'Preferred Foot','Jersey Number']]
for i in to_impute_by_mode.columns:
    fifa[i].fillna(fifa[i].mode()[0], inplace = True)

# %%
to_impute_by_median = fifa.loc[:, ['Weak Foot', 'Skill Moves', ]]
for i in to_impute_by_median.columns:
    fifa[i].fillna(fifa[i].median(), inplace = True)

# %%
fifa.head(20)
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %%
fifa.columns[fifa.isna().any()]
# Out:
# Index(['Club', 'Work Rate', 'Real Face', 'Position', 'Joined', 'Loaned From',
#        'Contract Valid Until', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
fifa.fillna(0,inplace = False)
fifa.head(20)
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %%
fifa.fillna(0,inplace = True)
fifa.head(20)
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %%
fifa["Nationality"]=='Argentina'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Nationality, Length: 18207, dtype: bool

# %%
Argentina=fifa[fifa["Nationality"]=='Argentina']
Argentina.head(11)
# Out:
#          ID         Name  Age Nationality  Overall  Potential  \
# 0    158023     L. Messi   31   Argentina       94         94
# 15   211110    P. Dybala   24   Argentina       89         94
# 23   153079    S. Agüero   30   Argentina       89         89
# 38   167664   G. Higuaín   30   Argentina       88         88
# 43   201399    M. Icardi   25   Argentina       87         90
# 89   192366  N. Otamendi   30   Argentina       85         85
# 138  183898  A. Di María   30   Argentina       84         84
# 142  178562    E. Banega   30   Argentina       84         84
# 151  143076     A. Gómez   30   Argentina       84         84
# 255  207471   F. Vázquez   29   Argentina       82         82
# 282  191180   J. Pastore   29   Argentina       82         82
#
#                     Club    Value   Wage  Special  ... Composure  Marking  \
# 0           FC Barcelona  €110.5M  €565K     2202  ...      96.0     33.0
# ...

# %%
Argentina.sort_values(by=['GKPositioning'],ascending=False).head()
# Out:
#           ID          Name  Age Nationality  Overall  Potential  \
# 749   226379       M. Díaz   32   Argentina       78         78
# 1294   14907   A. Bizzarri   40   Argentina       76         76
# 920   176919     N. Guzmán   32   Argentina       77         77
# 1053  201095  A. Marchesín   30   Argentina       77         77
# 4062  159520  N. Fernández   39   Argentina       71         71
#
#                        Club  Value  Wage  Special  ... Composure  Marking  \
# 749   Club Atlético Huracán    €6M  €15K     1143  ...      33.0     17.0
# 1294                 Foggia  €525K   €2K     1198  ...      60.0     11.0
# 920         Tigres U.A.N.L.    €5M  €38K     1334  ...      65.0     26.0
# 1053           Club América  €5.5M  €43K     1306  ...      64.0     22.0
# 4062      Unión de Santa Fe  €160K   €4K     1154  ...      60.0     18.0
#
#       StandingTackle  SlidingTackle GKDiving GKHandling GKKicking  \
# ...

# %%
Argentina.sort_values(by=['GKPositioning'],ascending=True).head()
# Out:
#            ID        Name  Age Nationality  Overall  Potential  \
# 13242  225590   I. Colman   23   Argentina       62         70
# 854    143001    C. Tévez   34   Argentina       78         78
# 491    193061  R. Pereyra   27   Argentina       80         80
# 14921  241001   F. Brener   20   Argentina       60         73
# 9759   221661   G. Vadalá   21   Argentina       66         76
#
#                                Club   Value  Wage  Special  ... Composure  \
# 13242        Club Atlético Aldosivi   €450K   €2K     1663  ...       0.0
# 854                    Boca Juniors     €5M  €26K     1933  ...      80.0
# 491                         Watford  €15.5M  €65K     2052  ...      78.0
# 14921           Belgrano de Córdoba   €400K   €2K     1528  ...      55.0
# 9759   CD Universidad de Concepción     €1M   €5K     1588  ...      54.0
#
#        Marking  StandingTackle  SlidingTackle GKDiving GKHandling GKKicking  \
# ...

# %%
Argentina.sort_values(by=['Overall'],ascending=True).head()
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 17987  241099  L. Finochietto   21   Argentina       51         59
# 17861  245726   F. Bustamante   19   Argentina       52         66
# 17638  236431      E. Alarcón   25   Argentina       53         57
# 17355  237125      V. Barbero   17   Argentina       54         73
# 17349  240955        T. Durso   19   Argentina       54         74
#
#                               Club  Value Wage  Special  ... Composure  \
# 17987           Argentinos Juniors   €40K  €1K      821  ...      33.0
# 17861          Club Atlético Tigre  €110K  €1K     1436  ...      44.0
# 17638                    Patronato   €50K  €2K      842  ...      47.0
# 17355          Belgrano de Córdoba  €140K  €1K     1397  ...      52.0
# 17349  Gimnasia y Esgrima La Plata  €120K  €1K      834  ...      37.0
#
#        Marking  StandingTackle  SlidingTackle GKDiving GKHandling GKKicking  \
# ...

# %%
Argentina.sort_values(by=['Overall'],ascending=False).head()
# Out:
#         ID        Name  Age Nationality  Overall  Potential             Club  \
# 0   158023    L. Messi   31   Argentina       94         94     FC Barcelona
# 23  153079   S. Agüero   30   Argentina       89         89  Manchester City
# 15  211110   P. Dybala   24   Argentina       89         94         Juventus
# 38  167664  G. Higuaín   30   Argentina       88         88            Milan
# 43  201399   M. Icardi   25   Argentina       87         90            Inter
#
#       Value   Wage  Special  ... Composure  Marking  StandingTackle  \
# 0   €110.5M  €565K     2202  ...      96.0     33.0            28.0
# 23   €64.5M  €300K     2107  ...      90.0     30.0            20.0
# 15     €89M  €205K     2092  ...      84.0     23.0            20.0
# 38     €57M  €245K     1965  ...      86.0     35.0            22.0
# 43   €64.5M  €130K     1940  ...      85.0     45.0            24.0
#
#     SlidingTackle GKDiving GKHandling GKKicking GKPositioning  GKReflexes  \
# ...

# %%
Argentina.sort_values(by=['Potential'],ascending=True).head()
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 17638  236431      E. Alarcón   25   Argentina       53         57
# 16813  245358       A. Cháves   26   Argentina       56         58
# 17987  241099  L. Finochietto   21   Argentina       51         59
# 15130  241090     J. Franzoni   27   Argentina       60         60
# 14012  239382      F. Otárola   32   Argentina       61         61
#
#                        Club  Value Wage  Special  ... Composure  Marking  \
# 17638             Patronato   €50K  €2K      842  ...      47.0     12.0
# 16813   Club Atlético Colón  €110K  €2K     1543  ...      54.0     51.0
# 17987    Argentinos Juniors   €40K  €1K      821  ...      33.0     15.0
# 15130             Patronato  €220K  €3K     1437  ...      49.0     25.0
# 14012  Club Deportes Temuco  €140K  €1K     1090  ...      45.0     11.0
#
#        StandingTackle  SlidingTackle GKDiving GKHandling GKKicking  \
# ...

# %%
Argentina.sort_values(by=['Composure'],ascending=True).head()
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 13242  225590       I. Colman   23   Argentina       62         70
# 4589   220624       L. Acosta   23   Argentina       71         79
# 11107  176922      F. Assmann   32   Argentina       64         64
# 10450  233088        G. Rehak   25   Argentina       65         71
# 11460  226675  F. Lanzillotta   25   Argentina       64         68
#
#                          Club  Value Wage  Special  ... Composure  Marking  \
# 13242  Club Atlético Aldosivi  €450K  €2K     1663  ...       0.0      0.0
# 4589      Belgrano de Córdoba  €2.6M  €6K     1244  ...       3.0     16.0
# 11107  Club Atlético Aldosivi  €260K  €2K     1050  ...      25.0     19.0
# 10450           Independiente  €525K  €4K      974  ...      28.0     22.0
# 11460      Argentinos Juniors  €425K  €2K      975  ...      30.0     18.0
#
#        StandingTackle  SlidingTackle GKDiving GKHandling GKKicking  \
# ...

# %%
Argentina.sort_values(by=['Marking'],ascending=True).head()
# Out:
#            ID          Name  Age Nationality  Overall  Potential  \
# 13242  225590     I. Colman   23   Argentina       62         70
# 15092  241584    J. Mendive   21   Argentina       60         69
# 14910  232549      M. Peano   19   Argentina       60         74
# 15150  231116  N. Temperini   23   Argentina       60         69
# 14112  245817    J. Vázquez   23   Argentina       61         67
#
#                          Club  Value Wage  Special  ... Composure  Marking  \
# 13242  Club Atlético Aldosivi  €450K  €2K     1663  ...       0.0      0.0
# 15092   Club Atlético Huracán  €240K  €1K      907  ...      40.0      7.0
# 14910       Unión de Santa Fe  €375K  €1K      908  ...      37.0      7.0
# 15150       Newell's Old Boys  €240K  €2K      968  ...      34.0     10.0
# 14112         Deportivo Pasto  €350K  €1K     1417  ...      54.0     10.0
#
#        StandingTackle  SlidingTackle GKDiving GKHandling GKKicking  \
# ...

# %%
Argentina.sort_values(by=['StandingTackle'],ascending=True).head()
# Out:
#            ID         Name  Age Nationality  Overall  Potential  \
# 13242  225590    I. Colman   23   Argentina       62         70
# 10695  184254     J. Ayala   30   Argentina       65         65
# 14963  233085     F. Costa   29   Argentina       60         61
# 3169   143598  L. Pocrnjic   36   Argentina       73         73
# 17638  236431   E. Alarcón   25   Argentina       53         57
#
#                          Club  Value Wage  Special  ... Composure  Marking  \
# 13242  Club Atlético Aldosivi  €450K  €2K     1663  ...       0.0      0.0
# 10695         Rosario Central  €350K  €3K      959  ...      44.0     15.0
# 14963               Patronato  €160K  €2K      903  ...      42.0     20.0
# 3169   Club Atlético Aldosivi  €550K  €5K     1002  ...      39.0     15.0
# 17638               Patronato   €50K  €2K      842  ...      47.0     12.0
#
#        StandingTackle  SlidingTackle GKDiving GKHandling GKKicking  \
# ...

# %%
Argentina[['Name','StandingTackle']].sort_values(by=['StandingTackle'],ascending=False).head()
# Out:
#              Name  StandingTackle
# 89    N. Otamendi            85.0
# 303      F. Fazio            85.0
# 510  M. Musacchio            84.0
# 712    D. Abraham            83.0
# 587  R. Battaglia            83.0

# %%
Argentina[['Name','Release Clause']].sort_values(by=['Release Clause'],ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 Argentina[['Name','Release Clause']].sort_values(by=['Release Clause'],ascending=False).head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:6955, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6952     if isinstance(ascending, (tuple, list)):
#    6953         ascending = ascending[0]
# -> 6955     indexer = nargsort(
#    6956         k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    6957     )
#    6958 else:
#    6959     if inplace:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\sorting.py:483, in nargsort(items, kind, ascending, na_position, key, mask)
#     481     non_nans = non_nans[::-1]
#     482     non_nan_idx = non_nan_idx[::-1]
# --> 483 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
# ...

# %%
fifa["Nationality"]=='Portugal'
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Nationality, Length: 18207, dtype: bool

# %%
Portugal=fifa[fifa["Nationality"]=='Portugal']
Portugal.head(11)
# Out:
#          ID               Name  Age Nationality  Overall  Potential  \
# 1     20801  Cristiano Ronaldo   33    Portugal       94         94
# 56   218667     Bernardo Silva   23    Portugal       86         91
# 108  120533               Pepe   35    Portugal       85         85
# 114  212198    Bruno Fernandes   23    Portugal       84         88
# 120  207566   William Carvalho   26    Portugal       84         86
# 126  199482           A. Lopes   27    Portugal       84         86
# 153   20775           Quaresma   34    Portugal       84         84
# 187  200888     Danilo Pereira   26    Portugal       83         86
# 194  197965              Pizzi   28    Portugal       83         83
# 213  178005       Rui Patrício   30    Portugal       83         83
# 233  227055     Gelson Martins   23    Portugal       82         87
#
#                         Club   Value   Wage  Special  ... Composure  Marking  \
# ...

# %%
fifa["Nationality"]=='Brazil'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Nationality, Length: 18207, dtype: bool

# %%
Brazil=fifa[fifa["Nationality"]=='Brazil']
Brazil.head(11)
# Out:
#         ID             Name  Age Nationality  Overall  Potential  \
# 2   190871        Neymar Jr   26      Brazil       92         93
# 27  200145         Casemiro   26      Brazil       88         90
# 32  189242         Coutinho   26      Brazil       88         89
# 35  176676          Marcelo   30      Brazil       88         88
# 39  164240     Thiago Silva   33      Brazil       88         88
# 57  210257          Ederson   24      Brazil       86         90
# 61  201942  Roberto Firmino   26      Brazil       86         87
# 64  191043      Alex Sandro   27      Brazil       86         86
# 65  190483    Douglas Costa   27      Brazil       86         86
# 75  135507      Fernandinho   33      Brazil       86         86
# 81  212831          Alisson   25      Brazil       85         90
#
#                    Club    Value   Wage  Special  ... Composure  Marking  \
# 2   Paris Saint-Germain  €118.5M  €290K     2143  ...      94.0     27.0
# ...

# %%
fifa['Name'].sort_values==['Age']
# Out:
# False

# %%
plt.figure(figsize=(12,4))
plt.style.use("fivethirtyeight")
#ax= sns.countplot("Position",data=fifa)
ax.set_xlabel(xlabel="Different Position in Football",fontsize=16)
ax.set_ylabel(ylabel="Count of Players",fontsize=16)
ax.set_title(label="Comparison of Positions and Players",fontsize=20)
plt.show()

# %%
some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbia')
data_countries = fifa.loc[fifa['Nationality'].isin(some_countries) & fifa['Overall']]
data_countries.head()
# Out:
#         ID          Name  Age Nationality  Overall  Potential  \
# 3   193080        De Gea   27       Spain       91         93
# 8   155862  Sergio Ramos   32       Spain       91         91
# 14  215914      N. Kanté   27      France       89         90
# 15  211110     P. Dybala   24   Argentina       89         94
# 16  202126       H. Kane   24     England       89         91
#
#                  Club   Value   Wage  Special  ... Composure  Marking  \
# 3   Manchester United    €72M  €260K     1471  ...      68.0     15.0
# 8         Real Madrid    €51M  €380K     2201  ...      82.0     87.0
# 14            Chelsea    €63M  €225K     2189  ...      85.0     90.0
# 15           Juventus    €89M  €205K     2092  ...      84.0     23.0
# 16  Tottenham Hotspur  €83.5M  €205K     2165  ...      89.0     56.0
#
#     StandingTackle  SlidingTackle GKDiving GKHandling GKKicking GKPositioning  \
# 3             21.0           13.0     90.0       85.0      87.0          88.0
# ...

# %%
plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.barplot(x = data_countries['Nationality'], y = data_countries['Overall'], palette = 'spring') # creating a bargraph
ax.set_xlabel(xlabel = 'Countries', fontsize = 9)
ax.set_ylabel(ylabel = 'Overall Scores', fontsize = 9)
ax.set_title(label = 'Distribution of overall scores of players from different countries', fontsize = 20)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
def Defending(row):
    fifa['Defending'] = fifa.apply(defending,axis=1)
    fifa['General'] = fifa.apply(general,axis=1)
    fifa['Mental'] = fifa.apply(mental,axis=1)
    fifa['Passing'] = fifa.apply(passing,axis=1)
    fifa['Mobility'] = fifa.apply(mobility,axis=1)
    fifa['Power'] = fifa.apply(power,axis=1)
    fifa['Rating'] = fifa.apply(rating,axis=1)
    fifa['Shooting'] = fifa.apply(shooting,axis=1)

# %%
fifa.head(4)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
#
#                   Club    Value   Wage  Special  ... Composure  Marking  \
# 0         FC Barcelona  €110.5M  €565K     2202  ...      96.0     33.0
# 1             Juventus     €77M  €405K     2228  ...      95.0     28.0
# 2  Paris Saint-Germain  €118.5M  €290K     2143  ...      94.0     27.0
# 3    Manchester United     €72M  €260K     1471  ...      68.0     15.0
#
#    StandingTackle  SlidingTackle GKDiving GKHandling GKKicking GKPositioning  \
# 0            28.0           26.0      6.0       11.0      15.0          14.0
# 1            31.0           23.0      7.0       11.0      15.0          14.0
# ...

# %%
x = fifa.Special
plt.figure(figsize = (12, 8))
plt.style.use('tableau-colorblind10')

ax = sns.distplot(x, bins = 66, kde = True, color = 'red')
ax.set_xlabel(xlabel = 'Special score range', fontsize = 14)
ax.set_ylabel(ylabel = 'Count of the Players',fontsize = 14)
ax.set_title(label = 'Histogram for the Speciality Scores of the Players', fontsize = 20)
plt.show()
